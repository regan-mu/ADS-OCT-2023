# %%
import pandas as pd
import os

# %%
data = pd.DataFrame()
for file in os.listdir("./Sales_Data/"):
    df = pd.read_csv("./Sales_Data/"+file)
    data = pd.concat([data, df])
data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
data.shape
# Out:
# (186850, 6)

# %%
data.to_csv("all_data.csv", index=False)

# %%
df = pd.read_csv("./all_data.csv")
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
df.shape
# Out:
# (186850, 6)

# %%
df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
df.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
df = df.dropna(axis=0)
df.isna().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
duplicates = df[df.duplicated()]
duplicates
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 31        176585  Bose SoundSport Headphones                 1       99.99
# 1149    Order ID                     Product  Quantity Ordered  Price Each
# 1155    Order ID                     Product  Quantity Ordered  Price Each
# 1302      177795    Apple Airpods Headphones                 1         150
# 1684      178158        USB-C Charging Cable                 1       11.95
# ...          ...                         ...               ...         ...
# 186563  Order ID                     Product  Quantity Ordered  Price Each
# 186632  Order ID                     Product  Quantity Ordered  Price Each
# 186738  Order ID                     Product  Quantity Ordered  Price Each
# 186782    259296    Apple Airpods Headphones                 1         150
# 186785    259297    Lightning Charging Cable                 1       14.95
#
#             Order Date                        Purchase Address
# ...

# %%
df = df.drop_duplicates()

# %%
df[df["Order Date"].str[0:2] == "Or"]
# Out:
#      Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 519  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#      Purchase Address
# 519  Purchase Address

# %%
df = df[df["Order Date"].str[0:2] != "Or"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185686 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185686 non-null  object
#  1   Product           185686 non-null  object
#  2   Quantity Ordered  185686 non-null  object
#  3   Price Each        185686 non-null  object
#  4   Order Date        185686 non-null  object
#  5   Purchase Address  185686 non-null  object
# dtypes: object(6)
# memory usage: 9.9+ MB

# %%
df["Quantity Ordered"] = pd.to_numeric(df["Quantity Ordered"])
df["Price Each"] = pd.to_numeric(df["Price Each"])
df["Order Date"] = pd.to_datetime(df["Order Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185686 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185686 non-null  object
#  1   Product           185686 non-null  object
#  2   Quantity Ordered  185686 non-null  int64
#  3   Price Each        185686 non-null  float64
#  4   Order Date        185686 non-null  datetime64[ns]
#  5   Purchase Address  185686 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 9.9+ MB

# %%
df["Month"] = df["Order Date"].dt.month
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185686 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185686 non-null  object
#  1   Product           185686 non-null  object
#  2   Quantity Ordered  185686 non-null  int64
#  3   Price Each        185686 non-null  float64
#  4   Order Date        185686 non-null  datetime64[ns]
#  5   Purchase Address  185686 non-null  object
#  6   Month             185686 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 11.3+ MB

# %%
df["Sales"] = df["Quantity Ordered"] * df["Price Each"]
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99

# %%
df["Sales"].sum()
# Out:
# 34465537.94

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  Month  \
# ...

# %%
best_month = df.groupby("Month")["Sales"].sum().reset_index(name="TotalSales")
best_month
# Out:
#     Month  TotalSales
# 0       1  1821413.16
# 1       2  2200078.08
# 2       3  2804973.35
# 3       4  3389217.98
# 4       5  3150616.23
# 5       6  2576280.15
# 6       7  2646461.32
# 7       8  2241083.37
# 8       9  2094465.69
# 9      10  3734777.86
# 10     11  3197875.05
# 11     12  4608295.70

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(best_month["Month"], best_month["TotalSales"]/1000000)
plt.ylabel("Sales in millions of USD")
plt.xlabel("Months")
plt.title("Monthly Sales Revenue")
plt.show()

# %%
# Dec with 4.6m sales.

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99

# %%
def get_city(x):
    city = x.split(",")[1].strip()
    return city

# %%
def get_state(x):
    state = x.split(",")[2].strip().split()[0].strip()
    return state

# %%
df["city"] = df["Purchase Address"].apply(lambda x: f"{get_city(x)}, {get_state(x)}")
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  Month  \
# ...

# %%
sales_per_city = df.groupby("city")["Sales"]\
    .sum()\
    .reset_index(name="TotalSales")\
    .sort_values(by="TotalSales", ascending=False)
sales_per_city
# Out:
#                 city  TotalSales
# 8  San Francisco, CA  8254743.55
# 4    Los Angeles, CA  5448304.28
# 5  New York City, NY  4661867.14
# 2         Boston, MA  3658627.65
# 0        Atlanta, GA  2794199.07
# 3         Dallas, TX  2765373.96
# 9        Seattle, WA  2745046.02
# 7       Portland, OR  1870010.56
# 1         Austin, TX  1818044.33
# 6       Portland, ME   449321.38

# %%
plt.figure(figsize=(14, 7))
plt.bar(sales_per_city["city"], sales_per_city["TotalSales"]/1000000)
plt.ylabel("City Sales in millions of USD")
plt.xlabel("City")
plt.title("Sales Revenue")
plt.xticks(rotation=45)
plt.show()

# %%
# City with highest sales San Francisco, CA with 8254743.55

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  Month  \
# ...

# %%
df["Hour"] = df["Order Date"].dt.hour
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#               city  Hour
# 0       Dallas, TX     8
# 2       Boston, MA    22
# ...

# %%
sales_by_hour = df.groupby("Hour")["Sales"].sum().reset_index(name="TotalSales")
sales_by_hour
# Out:
#     Hour  TotalSales
# 0      0   713548.66
# 1      1   460563.90
# 2      2   234839.45
# 3      3   145742.94
# 4      4   162546.07
# 5      5   230664.87
# 6      6   447963.01
# 7      7   744067.32
# 8      8  1192309.20
# 9      9  1638784.04
# 10    10  1942988.08
# 11    11  2296619.84
# 12    12  2314359.85
# 13    13  2152369.98
# 14    14  2082513.70
# 15    15  1940623.20
# 16    16  1902523.20
# 17    17  2126553.97
# 18    18  2218374.01
# 19    19  2411971.14
# 20    20  2280784.36
# 21    21  2040790.48
# 22    22  1606243.85
# 23    23  1177792.82

# %%
plt.figure(figsize=(12, 6))
plt.bar(sales_by_hour["Hour"], sales_by_hour["TotalSales"])
plt.title("Sales by Hour")
plt.xlabel("Hour")
plt.ylabel("Sales")
plt.xticks(ticks=sales_by_hour["Hour"], labels=(list(range(0, 24))))
plt.show()

# %%
duplicate_orderID = df[df.duplicated(subset="Order ID", keep=False)].copy()
duplicate_orderID
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 3        176560            Google Phone                 1      600.00
# 4        176560        Wired Headphones                 1       11.99
# 18       176574            Google Phone                 1      600.00
# 19       176574    USB-C Charging Cable                 1       11.95
# 32       176586  AAA Batteries (4-pack)                 2        2.99
# ...         ...                     ...               ...         ...
# 186792   259303   AA Batteries (4-pack)                 1        3.84
# 186803   259314        Wired Headphones                 1       11.99
# 186804   259314  AAA Batteries (4-pack)                 2        2.99
# 186841   259350            Google Phone                 1      600.00
# 186842   259350    USB-C Charging Cable                 1       11.95
#
#                 Order Date                        Purchase Address  Month  \
# ...

# %%
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  Month  \
# ...

# %%
duplicate_orderID["Grouped"] = duplicate_orderID.groupby("Order ID")["Product"].transform(lambda x: ",".join(x))
duplicate_orderID
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 3        176560            Google Phone                 1      600.00
# 4        176560        Wired Headphones                 1       11.99
# 18       176574            Google Phone                 1      600.00
# 19       176574    USB-C Charging Cable                 1       11.95
# 32       176586  AAA Batteries (4-pack)                 2        2.99
# ...         ...                     ...               ...         ...
# 186792   259303   AA Batteries (4-pack)                 1        3.84
# 186803   259314        Wired Headphones                 1       11.99
# 186804   259314  AAA Batteries (4-pack)                 2        2.99
# 186841   259350            Google Phone                 1      600.00
# 186842   259350    USB-C Charging Cable                 1       11.95
#
#                 Order Date                        Purchase Address  Month  \
# ...

# %%
unique_orders = duplicate_orderID.drop_duplicates(subset=["Order ID", "Grouped"])
unique_orders
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 3        176560              Google Phone                 1      600.00
# 18       176574              Google Phone                 1      600.00
# 32       176586    AAA Batteries (4-pack)                 2        2.99
# 119      176672  Lightning Charging Cable                 1       14.95
# 129      176681  Apple Airpods Headphones                 1      150.00
# ...         ...                       ...               ...         ...
# 186761   259277                    iPhone                 1      700.00
# 186783   259297                    iPhone                 1      700.00
# 186791   259303    34in Ultrawide Monitor                 1      379.99
# 186803   259314          Wired Headphones                 1       11.99
# 186841   259350              Google Phone                 1      600.00
#
#                 Order Date                        Purchase Address  Month  \
# ...

# %%
from itertools import combinations
from collections import Counter

# %%
count = Counter()
for row in unique_orders['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))
    
count.most_common(10)
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 1002),
#  (('Google Phone', 'USB-C Charging Cable'), 985),
#  (('iPhone', 'Wired Headphones'), 447),
#  (('Google Phone', 'Wired Headphones'), 413),
#  (('Vareebadd Phone', 'USB-C Charging Cable'), 361),
#  (('iPhone', 'Apple Airpods Headphones'), 360),
#  (('Google Phone', 'Bose SoundSport Headphones'), 220),
#  (('USB-C Charging Cable', 'Wired Headphones'), 159),
#  (('Vareebadd Phone', 'Wired Headphones'), 143),
#  (('Lightning Charging Cable', 'Wired Headphones'), 92)]

# %%
# iPhone', 'Lightning Charging Cable' are products that are often sold together.
